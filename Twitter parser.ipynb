# %%
import tweepy
from tweepy import OAuthHandler
 
consumer_key = 'sLV09OPi3alMMLRk0HRiCu0E7'
consumer_secret = 'iKesLG8B91nZLJ84Nc46TeLfhcppV9lDhF5yRFiVg1VNY9elJz'
access_token = '3317470103-A5IdrYg3u8cgAmbvvm8asO6JV2vs8UgXBpz0nP8'
access_secret = '6Np0ssKOPj903OPG3XZriGCFdgKAT93UWNU1YLuNVqykg'
 
auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
 
api = tweepy.API(auth)

# %%
for status in tweepy.Cursor(api.home_timeline).items(10):
    print(status.text)
# Out:
# Доброе утро, любимые! https://t.co/RSFdlsfI2t
# 🇪🇸 @CesarAzpi and 🇧🇷 @willianborges88 were both in action yesterday as preparations for the World Cup continue... https://t.co/R865OcXLsO
# If the acquisition was necessary and the rumors are to be believed, I think @github chose the perfect tech giant.… https://t.co/MQpIbALHHZ
# RT @teamretrorabbit: Our Rabbits are taking over the next Google Developer Group Meetup on 6 June! First Kimi Beyl will be discussing "When…
# Organizers:NGO“Open Policy Foundation”,the Ministry of Education and Science of Ukraine,with the support of the UNI… https://t.co/rmllgYwBkI
# On June 4, at 11 AM, a press conference will be held on the topic “Entry Campaign-2018 for Applicants from the Non-… https://t.co/ryrjs2sZzo
# Організатори: ГО «Фонд «Відкрита політика», Міністерство освіти і науки України, за підтримки ЮНІСЕФ
# ГО «Фонд «Відк… https://t.co/bhT1arwkeG
# 4 червня об 11:00 відбудеться прес-конференція на тему «Вступна кампанія-2018 для абітурієнтів із непідконтрольних… https://t.co/xHnPaGmjj5
# New Post: Java Weekly, Issue 231 https://t.co/mndycwOnL0 https://t.co/2SrDdIZWyj
# RT @betsythemuffin: Underrated programming techniques: name something (a step definitions file, a class, a directory, whatever....) "junk d…

# %%
from tweepy import Stream
from tweepy.streaming import StreamListener
 
class MyListener(StreamListener):
 
    def on_data(self, data):
        try:
            with open('twitter.json', 'a') as f:
                f.write(data)
                return True
        except BaseException as e:
            print("Error on_data: %s" % str(e))
        return True
 
    def on_error(self, status):
        print(status)
        return True

# %%
def listen(tags = ['#android']):
    twitter_stream = Stream(auth, MyListener())
    twitter_stream.filter(track = tags)

# %%
from threading import Thread
thread = Thread(target = listen)
thread.start()

# %%
with open('twitter.json', 'r') as f:
    print(f.readlines())
# Out:
# ['{"created_at":"Mon Jun 04 07:38:10 +0000 2018","id":1003541406126706688,"id_str":"1003541406126706688","text":"\\u3010#RETWEET\\u3011#TFBJP #TEAMFAIRYROSE #500aday #AutoFollow #OpenFollow #SougoFollow #90sBabyFollowTrain #FollowMe #android 11","source":"\\u003ca href=\\"http:\\/\\/twittbot.net\\/\\" rel=\\"nofollow\\"\\u003etwittbot.net\\u003c\\/a\\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":2202499946,"id_str":"2202499946","name":"Strongest ExpectNuya","screen_name":"SE_Nuya","location":"Melbourne - Australia","url":null,"description":"Just simple | All about my life","translator_type":"none","protected":false,"verified":false,"followers_count":508,"friends_count":61,"listed_count":97,"favourites_count":0,"statuses_count":51976,"created_at":"Tue Nov 19 04:50:47 +0000 2013","utc_offset":null,"time_zone":null,"geo_enabled":true,"lang":"id","contributors_enabled":false,"is_translator":false,"profile_background_color":"C0DEED","profile_background_image_url":"http:\\/\\/abs.twimg.com\\/images\\/themes\\/theme1\\/bg.png","profile_background_image_url_https":"https:\\/\\/abs.twimg.com\\/images\\/themes\\/theme1\\/bg.png","profile_background_tile":true,"profile_link_color":"0084B4","profile_sidebar_border_color":"FFFFFF","profile_sidebar_fill_color":"DDEEF6","profile_text_color":"333333","profile_use_background_image":true,"profile_image_url":"http:\\/\\/pbs.twimg.com\\/profile_images\\/378800000761139812\\/9c9c60cb83888d8e6363a9a3e4d14705_normal.jpeg","profile_image_url_https":"https:\\/\\/pbs.twimg.com\\/profile_images\\/378800000761139812\\/9c9c60cb83888d8e6363a9a3e4d14705_normal.jpeg","profile_banner_url":"https:\\/\\/pbs.twimg.com\\/profile_banners\\/2202499946\\/1384864214","default_profile":false,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null},"geo":null,"coordinates":null,"place":null,"contributors":null,"is_quote_status":false,"quote_count":0,"reply_count":0,"retweet_count":0,"favorite_count":0,"entities":{"hashtags":[{"text":"RETWEET","indices":[1,9]},{"text":"TFBJP","indices":[10,16]},{"text":"TEAMFAIRYROSE","indices":[17,31]},{"text":"500aday","indices":[32,40]},{"text":"AutoFollow","indices":[41,52]},{"text":"OpenFollow","indices":[53,64]},{"text":"SougoFollow","indices":[65,77]},{"text":"90sBabyFollowTrain","indices":[78,97]},{"text":"FollowMe","indices":[98,107]},{"text":"android","indices":[108,116]}],"urls":[],"user_mentions":[],"symbols":[]},"favorited":false,"retweeted":false,"filter_level":"low","lang":"und","timestamp_ms":"1528097890775"}\n', '{"created_at":"Mon Jun 04 07:38:23 +0000 2018","id":1003541457490173953,"id_str":"1003541457490173953","text":"I just crammed 291 photos and saved 511 mb with #Cramapp. Try free today: https:\\/\\/t.co\\/HGvnOPLrGS #android #ios #mobile","source":"","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":787850561722933249,"id_str":"787850561722933249","name":"Rizwan Arsh","screen_name":"RizwanArsh2","location":null,"url":null,"description":null,"translator_type":"none","protected":false,"verified":false,"followers_count":4,"friends_count":0,"listed_count":0,"favourites_count":0,"statuses_count":4,"created_at":"Mon Oct 17 02:59:46 +0000 2016","utc_offset":null,"time_zone":null,"geo_enabled":false,"lang":"en-gb","contributors_enabled":false,"is_translator":false,"profile_background_color":"F5F8FA","profile_background_image_url":"","profile_background_image_url_https":"","profile_background_tile":false,"profile_link_color":"1DA1F2","profile_sidebar_border_color":"C0DEED","profile_sidebar_fill_color":"DDEEF6","profile_text_color":"333333","profile_use_background_image":true,"profile_image_url":"http:\\/\\/abs.twimg.com\\/sticky\\/default_profile_images\\/default ...
# Exception in thread Thread-5:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-6bbdc0bb30ad>", line 3, in listen
#     twitter_stream.filter(track = tags)
#   File "/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tweepy/streaming.py", line 428, in filter
#     self._start(async)
#   File "/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tweepy/streaming.py", line 346, in _start
#     self._run()
#   File "/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tweepy/streaming.py", line 286, in _run
#     raise
# RuntimeError: No active exception to reraise
